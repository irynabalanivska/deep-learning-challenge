# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
# WARNING:tensorflow:From C:\Users\sampl\anaconda3.1\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(['EIN', 'NAME'], axis=1)

# %%
# Determine the number of unique values in each column.
unique_values = application_df.nunique()
print(unique_values)
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_type_counts = application_df['APPLICATION_TYPE'].value_counts()
print(application_type_counts)
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
# First, look at APPLICATION_TYPE value counts for binning
application_type_counts = application_df['APPLICATION_TYPE'].value_counts()

# Next, determine which values to replace
cutoff = 500 
application_types_to_replace = application_type_counts[application_type_counts < cutoff].index.tolist()

# Then, replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Finally, check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_counts = application_df['CLASSIFICATION'].value_counts()
print(classification_counts)
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_counts = application_df['CLASSIFICATION'].value_counts()
classification_counts_gt1 = classification_counts[classification_counts > 1]
print(classification_counts_gt1)
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
# First, look at CLASSIFICATION value counts for binning
classification_counts = application_df['CLASSIFICATION'].value_counts()

# Next, determine which values to replace if their count is below a certain cutoff
cutoff = 500
classifications_to_replace = classification_counts[classification_counts < cutoff].index.tolist()

# Then, replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Finally, check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Other     1484
# C7000      777
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df_dummies = pd.get_dummies(application_df)

# Display the first few rows of the new DataFrame to verify the transformation
application_df_dummies.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0       1     5000              1                   False
# 1       1   108590              1                   False
# 2       1     5000              0                   False
# 3       1     6692              1                   False
# 4       1   142590              1                   False
#
#    APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                  True                 False                False
# 1                 False                 False                 True
# 2                 False                 False                False
# 3                 False                 False                 True
# 4                 False                 False                 True
#
#    APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                False                False                False  ...
# 1                False                False                False  ...
# 2                False                 True                False  ...
# 3                False                False                False  ...
# 4                False                False                False  ...
#
#    INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0              False                   False                     False
# 1               True                   False                     False
# 2              False                   False                     False
# 3              False                    True                     False
# 4              False                   False                      True
#
#    INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0               False             False                   False
# 1               False             False                   False
# 2               False             False                   False
# 3               False             False                   False
# 4               False             False                   False
#
#    INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0            False              False                      True
# 1            False              False                      True
# 2            False              False                      True
# 3            False              False                      True
# 4            False              False                      True
#
#    SPECIAL_CONSIDERATIONS_Y
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
# [5 rows x 45 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = application_df_dummies['IS_SUCCESSFUL'].values
X = application_df_dummies.drop(['IS_SUCCESSFUL'], axis=1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Convert data types to float32, for model training below. 
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
y_train = y_train.astype('float32')
y_test = y_test.astype('float32')

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
n_features = X_train.shape[1]
number_hidden_nodes_layer1 = 100
number_hidden_nodes_layer2 = 100

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=number_hidden_nodes_layer1, input_dim=n_features, activation='relu'))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=number_hidden_nodes_layer2, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# WARNING:tensorflow:From C:\Users\sampl\anaconda3.1\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               4500
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  dense_2 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 14701 (57.43 KB)
# Trainable params: 14701 (57.43 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\sampl\anaconda3.1\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# Train the model
history = nn.fit(X_train, y_train, epochs=150, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/150
# WARNING:tensorflow:From C:\Users\sampl\anaconda3.1\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\sampl\anaconda3.1\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 644/644 [==============================] - 6s 7ms/step - loss: 70515.5078 - accuracy: 0.4884 - val_loss: 9446.4199 - val_accuracy: 0.4810
# Epoch 2/150
# 644/644 [==============================] - 4s 6ms/step - loss: 84356.8125 - accuracy: 0.4860 - val_loss: 6834.8003 - val_accuracy: 0.4810
# Epoch 3/150
# 644/644 [==============================] - 4s 6ms/step - loss: 60580.1445 - accuracy: 0.5093 - val_loss: 132.9165 - val_accuracy: 0.4958
# Epoch 4/150
# 644/644 [==============================] - 4s 6ms/step - loss: 15431.1514 - accuracy: 0.5002 - val_loss: 877.2034 - val_accuracy: 0.4810
# Epoch 5/150
# 644/644 [==============================] - 3s 5ms/step - loss: 13560.1416 - accuracy: 0.5095 - val_loss: 1625.7369 - val_accuracy: 0.5190
# Epoch 6/150
# 644/644 [==============================] - 3s 5ms/step - loss: 13939.0703 - accuracy: 0.5009 - val_loss: 23672.0781 - val_accuracy: 0.5190
# Epoch 7/150
# 644/644 [==============================] - 3s 5ms/step - loss: 42847.3242 - accuracy: 0.4963 - val_loss: 3259.2461 - val_accuracy: 0.4810
# Epoch 8/150
# 644/644 [==============================] - 3s 5ms/step - loss: 20793.3457 - accuracy: 0.5019 - val_loss: 4566.3223 - val_accuracy: 0.4810
# Epoch 9/150
# 644/644 [==============================] - 3s 5ms/step - loss: 9087.3086 - accuracy: 0.5074 - val_loss: 61821.9805 - val_accuracy: 0.5190
# Epoch 10/150
# 644/644 [==============================] - 3s 5ms/step - loss: 13106.0732 - accuracy: 0.4911 - val_loss: 19251.5586 - val_accuracy: 0.5190
# Epoch 11/150
# 644/644 [==============================] - 3s 5ms/step - loss: 1968.6229 - accuracy: 0.5100 - val_loss: 4968.2891 - val_accuracy: 0.5190
# Epoch 12/150
# 644/644 [==============================] - 3s 5ms/step - loss: 4446.5649 - accuracy: 0.4844 - val_loss: 21570.8965 - val_accuracy: 0.5190
# Epoch 13/150
# 644/644 [==============================] - 3s 5ms/step - loss: 1889.4584 - accuracy: 0.5293 - val_loss: 0.7805 - val_accuracy: 0.5190
# Epoch 14/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.7071 - accuracy: 0.5350 - val_loss: 0.6950 - val_accuracy: 0.5190
# Epoch 15/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6910 - accuracy: 0.5350 - val_loss: 0.6931 - val_accuracy: 0.5190
# Epoch 16/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6908 - accuracy: 0.5350 - val_loss: 0.6931 - val_accuracy: 0.5190
# Epoch 17/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6908 - accuracy: 0.5350 - val_loss: 0.6931 - val_accuracy: 0.5190
# Epoch 18/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6908 - accuracy: 0.5350 - val_loss: 0.6934 - val_accuracy: 0.5190
# Epoch 19/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6908 - accuracy: 0.5350 - val_loss: 0.6928 - val_accuracy: 0.5190
# Epoch 20/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6908 - accuracy: 0.5350 - val_loss: 0.6926 - val_accuracy: 0.5190
# Epoch 21/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6908 - accuracy: 0.5350 - val_loss: 0.6925 - val_accuracy: 0.5190
# Epoch 22/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6908 - accuracy: 0.5350 - val_loss: 0.6935 - val_accuracy: 0.5190
# Epoch 23/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6908 - accuracy: 0.5350 - val_loss: 0.6931 - val_accuracy: 0.5190
# Epoch 24/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6907 - accuracy: 0.5350 - val_loss: 0.6941 - val_accuracy: 0.5190
# Epoch 25/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6909 - accuracy: 0.5350 - val_loss: 0.6928 - val_accuracy: 0.5190
# Epoch 26/150
# 644/644 [==============================] - 4s 5ms/step - loss: 0.6908 - accuracy: 0.5350 - val_loss: 0.6926 - val_accuracy: 0.5190
# Epoch 27/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6908 - accuracy: 0.5350 - val_loss: 0.6926 - val_accuracy: 0.5190
# Epoch 28/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6908 - accuracy: 0.5350 - val_loss: 0.6933 - val_accuracy: 0.5190
# Epoch 29/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6909 - accuracy: 0.5350 - val_loss: 0.6933 - val_accuracy: 0.5190
# Epoch 30/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6908 - accuracy: 0.5350 - val_loss: 0.6925 - val_accuracy: 0.5190
# Epoch 31/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6908 - accuracy: 0.5350 - val_loss: 0.6930 - val_accuracy: 0.5190
# Epoch 32/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6908 - accuracy: 0.5350 - val_loss: 0.6932 - val_accuracy: 0.5190
# Epoch 33/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6908 - accuracy: 0.5350 - val_loss: 0.6946 - val_accuracy: 0.5190
# Epoch 34/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6908 - accuracy: 0.5350 - val_loss: 0.6925 - val_accuracy: 0.5190
# Epoch 35/150
# 644/644 [==============================] - 4s 5ms/step - loss: 0.6909 - accuracy: 0.5350 - val_loss: 0.6929 - val_accuracy: 0.5190
# Epoch 36/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6909 - accuracy: 0.5350 - val_loss: 0.6928 - val_accuracy: 0.5190
# Epoch 37/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6907 - accuracy: 0.5350 - val_loss: 0.6928 - val_accuracy: 0.5190
# Epoch 38/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6909 - accuracy: 0.5350 - val_loss: 0.6930 - val_accuracy: 0.5190
# Epoch 39/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6908 - accuracy: 0.5350 - val_loss: 0.6925 - val_accuracy: 0.5190
# Epoch 40/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6908 - accuracy: 0.5350 - val_loss: 0.6927 - val_accuracy: 0.5190
# Epoch 41/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6908 - accuracy: 0.5350 - val_loss: 0.6925 - val_accuracy: 0.5190
# Epoch 42/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6909 - accuracy: 0.5350 - val_loss: 0.6925 - val_accuracy: 0.5190
# Epoch 43/150
# 644/644 [==============================] - 4s 5ms/step - loss: 0.6908 - accuracy: 0.5350 - val_loss: 0.6948 - val_accuracy: 0.5190
# Epoch 44/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6908 - accuracy: 0.5350 - val_loss: 0.6938 - val_accuracy: 0.5190
# Epoch 45/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6910 - accuracy: 0.5350 - val_loss: 0.6934 - val_accuracy: 0.5190
# Epoch 46/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6910 - accuracy: 0.5350 - val_loss: 0.6929 - val_accuracy: 0.5190
# Epoch 47/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6909 - accuracy: 0.5350 - val_loss: 0.6956 - val_accuracy: 0.5190
# Epoch 48/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6911 - accuracy: 0.5350 - val_loss: 0.6939 - val_accuracy: 0.5190
# Epoch 49/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6909 - accuracy: 0.5350 - val_loss: 0.6928 - val_accuracy: 0.5190
# Epoch 50/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6912 - accuracy: 0.5350 - val_loss: 0.6938 - val_accuracy: 0.5190
# Epoch 51/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6911 - accuracy: 0.5329 - val_loss: 0.6939 - val_accuracy: 0.5190
# Epoch 52/150
# 644/644 [==============================] - 5s 8ms/step - loss: 0.6910 - accuracy: 0.5339 - val_loss: 0.6947 - val_accuracy: 0.5190
# Epoch 53/150
# 644/644 [==============================] - 5s 8ms/step - loss: 0.6913 - accuracy: 0.5335 - val_loss: 0.6934 - val_accuracy: 0.5190
# Epoch 54/150
# 644/644 [==============================] - 5s 8ms/step - loss: 0.6909 - accuracy: 0.5350 - val_loss: 0.6925 - val_accuracy: 0.5190
# Epoch 55/150
# 644/644 [==============================] - 5s 7ms/step - loss: 0.6911 - accuracy: 0.5338 - val_loss: 0.6928 - val_accuracy: 0.5190
# Epoch 56/150
# 644/644 [==============================] - 5s 8ms/step - loss: 0.6913 - accuracy: 0.5323 - val_loss: 0.6940 - val_accuracy: 0.5190
# Epoch 57/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6915 - accuracy: 0.5350 - val_loss: 0.6926 - val_accuracy: 0.5190
# Epoch 58/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6913 - accuracy: 0.5328 - val_loss: 0.6929 - val_accuracy: 0.5190
# Epoch 59/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6911 - accuracy: 0.5350 - val_loss: 0.6925 - val_accuracy: 0.5190
# Epoch 60/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6915 - accuracy: 0.5350 - val_loss: 0.6939 - val_accuracy: 0.5190
# Epoch 61/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6913 - accuracy: 0.5350 - val_loss: 0.6926 - val_accuracy: 0.5190
# Epoch 62/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6913 - accuracy: 0.5313 - val_loss: 0.6927 - val_accuracy: 0.5190
# Epoch 63/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6913 - accuracy: 0.5350 - val_loss: 0.6945 - val_accuracy: 0.5190
# Epoch 64/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6916 - accuracy: 0.5337 - val_loss: 0.6937 - val_accuracy: 0.5190
# Epoch 65/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6915 - accuracy: 0.5325 - val_loss: 0.6932 - val_accuracy: 0.5190
# Epoch 66/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6915 - accuracy: 0.5310 - val_loss: 0.6938 - val_accuracy: 0.5190
# Epoch 67/150
# 644/644 [==============================] - 4s 7ms/step - loss: 0.6913 - accuracy: 0.5337 - val_loss: 0.6945 - val_accuracy: 0.5190
# Epoch 68/150
# 644/644 [==============================] - 5s 8ms/step - loss: 0.6912 - accuracy: 0.5350 - val_loss: 0.6959 - val_accuracy: 0.5190
# Epoch 69/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6913 - accuracy: 0.5344 - val_loss: 0.6935 - val_accuracy: 0.5190
# Epoch 70/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6910 - accuracy: 0.5350 - val_loss: 0.6936 - val_accuracy: 0.5190
# Epoch 71/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6913 - accuracy: 0.5350 - val_loss: 0.6964 - val_accuracy: 0.5190
# Epoch 72/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6914 - accuracy: 0.5324 - val_loss: 0.6947 - val_accuracy: 0.5190
# Epoch 73/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6913 - accuracy: 0.5322 - val_loss: 0.6951 - val_accuracy: 0.5190
# Epoch 74/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6912 - accuracy: 0.5350 - val_loss: 0.6926 - val_accuracy: 0.5190
# Epoch 75/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6912 - accuracy: 0.5315 - val_loss: 0.6928 - val_accuracy: 0.5190
# Epoch 76/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6912 - accuracy: 0.5349 - val_loss: 0.6932 - val_accuracy: 0.4810
# Epoch 77/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6915 - accuracy: 0.5343 - val_loss: 0.6933 - val_accuracy: 0.5190
# Epoch 78/150
# 644/644 [==============================] - 4s 7ms/step - loss: 0.6910 - accuracy: 0.5326 - val_loss: 0.6927 - val_accuracy: 0.5190
# Epoch 79/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6911 - accuracy: 0.5334 - val_loss: 0.6929 - val_accuracy: 0.5190
# Epoch 80/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6911 - accuracy: 0.5339 - val_loss: 0.6950 - val_accuracy: 0.5190
# Epoch 81/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6910 - accuracy: 0.5320 - val_loss: 0.6925 - val_accuracy: 0.5190
# Epoch 82/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6913 - accuracy: 0.5350 - val_loss: 0.6930 - val_accuracy: 0.5190
# Epoch 83/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6914 - accuracy: 0.5350 - val_loss: 0.6942 - val_accuracy: 0.5190
# Epoch 84/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6912 - accuracy: 0.5350 - val_loss: 0.6934 - val_accuracy: 0.5190
# Epoch 85/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6911 - accuracy: 0.5350 - val_loss: 0.6935 - val_accuracy: 0.5190
# Epoch 86/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6912 - accuracy: 0.5333 - val_loss: 0.6943 - val_accuracy: 0.5190
# Epoch 87/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6913 - accuracy: 0.5350 - val_loss: 0.6934 - val_accuracy: 0.5190
# Epoch 88/150
# 644/644 [==============================] - 4s 7ms/step - loss: 0.6913 - accuracy: 0.5350 - val_loss: 0.6926 - val_accuracy: 0.5190
# Epoch 89/150
# 644/644 [==============================] - 5s 8ms/step - loss: 0.6913 - accuracy: 0.5337 - val_loss: 0.6933 - val_accuracy: 0.5190
# Epoch 90/150
# 644/644 [==============================] - 5s 7ms/step - loss: 0.6911 - accuracy: 0.5350 - val_loss: 0.6926 - val_accuracy: 0.5190
# Epoch 91/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6914 - accuracy: 0.5342 - val_loss: 0.6926 - val_accuracy: 0.5190
# Epoch 92/150
# 644/644 [==============================] - 4s 5ms/step - loss: 0.6914 - accuracy: 0.5324 - val_loss: 0.6947 - val_accuracy: 0.5190
# Epoch 93/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6912 - accuracy: 0.5344 - val_loss: 0.6925 - val_accuracy: 0.5190
# Epoch 94/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6911 - accuracy: 0.5350 - val_loss: 0.6941 - val_accuracy: 0.5190
# Epoch 95/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6913 - accuracy: 0.5350 - val_loss: 0.6924 - val_accuracy: 0.5190
# Epoch 96/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6913 - accuracy: 0.5346 - val_loss: 0.6932 - val_accuracy: 0.5190
# Epoch 97/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6912 - accuracy: 0.5350 - val_loss: 0.6964 - val_accuracy: 0.5190
# Epoch 98/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6911 - accuracy: 0.5338 - val_loss: 0.6939 - val_accuracy: 0.5190
# Epoch 99/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6914 - accuracy: 0.5332 - val_loss: 0.6930 - val_accuracy: 0.5190
# Epoch 100/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6913 - accuracy: 0.5350 - val_loss: 0.6929 - val_accuracy: 0.5190
# Epoch 101/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6911 - accuracy: 0.5336 - val_loss: 0.6928 - val_accuracy: 0.5190
# Epoch 102/150
# 644/644 [==============================] - 4s 7ms/step - loss: 0.6911 - accuracy: 0.5315 - val_loss: 0.6929 - val_accuracy: 0.5190
# Epoch 103/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6911 - accuracy: 0.5350 - val_loss: 0.6926 - val_accuracy: 0.5190
# Epoch 104/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6912 - accuracy: 0.5350 - val_loss: 0.6924 - val_accuracy: 0.5190
# Epoch 105/150
# 644/644 [==============================] - 5s 7ms/step - loss: 0.6911 - accuracy: 0.5350 - val_loss: 0.6934 - val_accuracy: 0.5190
# Epoch 106/150
# 644/644 [==============================] - 5s 9ms/step - loss: 0.6910 - accuracy: 0.5336 - val_loss: 0.6938 - val_accuracy: 0.5190
# Epoch 107/150
# 644/644 [==============================] - 6s 9ms/step - loss: 0.6912 - accuracy: 0.5350 - val_loss: 0.6925 - val_accuracy: 0.5190
# Epoch 108/150
# 644/644 [==============================] - 5s 8ms/step - loss: 0.6912 - accuracy: 0.5350 - val_loss: 0.6933 - val_accuracy: 0.5190
# Epoch 109/150
# 644/644 [==============================] - 5s 7ms/step - loss: 0.6912 - accuracy: 0.5350 - val_loss: 0.6926 - val_accuracy: 0.5190
# Epoch 110/150
# 644/644 [==============================] - 4s 7ms/step - loss: 0.6911 - accuracy: 0.5329 - val_loss: 0.6940 - val_accuracy: 0.5190
# Epoch 111/150
# 644/644 [==============================] - 4s 5ms/step - loss: 0.6912 - accuracy: 0.5350 - val_loss: 0.6932 - val_accuracy: 0.5190
# Epoch 112/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6911 - accuracy: 0.5350 - val_loss: 0.6927 - val_accuracy: 0.5190
# Epoch 113/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6910 - accuracy: 0.5350 - val_loss: 0.6924 - val_accuracy: 0.5190
# Epoch 114/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6913 - accuracy: 0.5350 - val_loss: 0.6938 - val_accuracy: 0.5190
# Epoch 115/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6912 - accuracy: 0.5350 - val_loss: 0.6930 - val_accuracy: 0.5190
# Epoch 116/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6912 - accuracy: 0.5350 - val_loss: 0.6947 - val_accuracy: 0.5190
# Epoch 117/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6912 - accuracy: 0.5350 - val_loss: 0.6926 - val_accuracy: 0.5190
# Epoch 118/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6910 - accuracy: 0.5350 - val_loss: 0.6924 - val_accuracy: 0.5190
# Epoch 119/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6912 - accuracy: 0.5350 - val_loss: 0.6930 - val_accuracy: 0.5190
# Epoch 120/150
# 644/644 [==============================] - 4s 5ms/step - loss: 0.6908 - accuracy: 0.5336 - val_loss: 0.6934 - val_accuracy: 0.5190
# Epoch 121/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6913 - accuracy: 0.5350 - val_loss: 0.6932 - val_accuracy: 0.5190
# Epoch 122/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6912 - accuracy: 0.5334 - val_loss: 0.6948 - val_accuracy: 0.5190
# Epoch 123/150
# 644/644 [==============================] - 4s 5ms/step - loss: 0.6911 - accuracy: 0.5350 - val_loss: 0.6928 - val_accuracy: 0.5190
# Epoch 124/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6910 - accuracy: 0.5350 - val_loss: 0.6926 - val_accuracy: 0.5190
# Epoch 125/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6913 - accuracy: 0.5350 - val_loss: 0.6925 - val_accuracy: 0.5190
# Epoch 126/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6910 - accuracy: 0.5333 - val_loss: 0.6925 - val_accuracy: 0.5190
# Epoch 127/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6912 - accuracy: 0.5350 - val_loss: 0.6926 - val_accuracy: 0.5190
# Epoch 128/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6910 - accuracy: 0.5350 - val_loss: 0.6924 - val_accuracy: 0.5190
# Epoch 129/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6912 - accuracy: 0.5350 - val_loss: 0.6929 - val_accuracy: 0.5190
# Epoch 130/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6911 - accuracy: 0.5350 - val_loss: 0.6927 - val_accuracy: 0.5190
# Epoch 131/150
# 644/644 [==============================] - 4s 5ms/step - loss: 0.6911 - accuracy: 0.5350 - val_loss: 0.6952 - val_accuracy: 0.5190
# Epoch 132/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6910 - accuracy: 0.5333 - val_loss: 0.6930 - val_accuracy: 0.5190
# Epoch 133/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6912 - accuracy: 0.5350 - val_loss: 0.6940 - val_accuracy: 0.5190
# Epoch 134/150
# 644/644 [==============================] - 4s 7ms/step - loss: 0.6911 - accuracy: 0.5350 - val_loss: 0.6926 - val_accuracy: 0.5190
# Epoch 135/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6912 - accuracy: 0.5350 - val_loss: 0.6924 - val_accuracy: 0.5190
# Epoch 136/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6913 - accuracy: 0.5350 - val_loss: 0.6924 - val_accuracy: 0.5190
# Epoch 137/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6911 - accuracy: 0.5350 - val_loss: 0.6939 - val_accuracy: 0.5190
# Epoch 138/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6910 - accuracy: 0.5339 - val_loss: 0.6940 - val_accuracy: 0.5190
# Epoch 139/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6912 - accuracy: 0.5350 - val_loss: 0.6925 - val_accuracy: 0.5190
# Epoch 140/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6910 - accuracy: 0.5350 - val_loss: 0.6924 - val_accuracy: 0.5190
# Epoch 141/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6912 - accuracy: 0.5350 - val_loss: 0.6925 - val_accuracy: 0.5190
# Epoch 142/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6910 - accuracy: 0.5350 - val_loss: 0.6925 - val_accuracy: 0.5190
# Epoch 143/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6910 - accuracy: 0.5350 - val_loss: 0.6930 - val_accuracy: 0.5190
# Epoch 144/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6910 - accuracy: 0.5350 - val_loss: 0.6947 - val_accuracy: 0.5190
# Epoch 145/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6911 - accuracy: 0.5350 - val_loss: 0.6937 - val_accuracy: 0.5190
# Epoch 146/150
# 644/644 [==============================] - 3s 5ms/step - loss: 0.6911 - accuracy: 0.5350 - val_loss: 0.6925 - val_accuracy: 0.5190
# Epoch 147/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6911 - accuracy: 0.5328 - val_loss: 0.6960 - val_accuracy: 0.5190
# Epoch 148/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6911 - accuracy: 0.5350 - val_loss: 0.6935 - val_accuracy: 0.5190
# Epoch 149/150
# 644/644 [==============================] - 4s 7ms/step - loss: 0.6909 - accuracy: 0.5350 - val_loss: 0.6975 - val_accuracy: 0.5190
# Epoch 150/150
# 644/644 [==============================] - 4s 6ms/step - loss: 0.6912 - accuracy: 0.5350 - val_loss: 0.6934 - val_accuracy: 0.5190

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 1.0474 - accuracy: 0.4316 - 1s/epoch - 4ms/step
# Loss: 1.0473722219467163, Accuracy: 0.43160349130630493

# %%
# Export our model to HDF5 file
nn.save("AlphabetSoupCharity_Optimization_2.h5")
# Out:
# C:\Users\sampl\anaconda3.1\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
